# %% [markdown]
# <a href="https://colab.research.google.com/github/mnhtm187/Minh-T-m-31241027094/blob/main/Digits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images.reshape(60000, 28*28).astype('float32') / 255
test_images = test_images.reshape(10000, 784).astype('float32') / 255

train_labels_cat = to_categorical(train_labels)
test_labels_cat = to_categorical(test_labels)


network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(784,)))
network.add(Dropout(0.2))
network.add(layers.Dense(256, activation='relu'))
network.add(Dropout(0.2))
network.add(layers.Dense(10, activation='softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_images, train_labels_cat,
                      epochs=100,
                      batch_size=128,
                      validation_data=(test_images, test_labels_cat))


test_loss, test_acc = network.evaluate(test_images, test_labels_cat)
print(' Test accuracy:', test_acc)


img_path = '/content/drive/MyDrive/digit/3.webp'
img = load_img(img_path, color_mode='grayscale', target_size=(28, 28))
img = img_to_array(img)
img = img.astype('float32') / 255.0
img = img.reshape(1, 784)

pred = network.predict(img)
predicted_digit = np.argmax(pred)

print(" Dự đoán ảnh từ file là:", predicted_digit)

digit = train_images[100].reshape(28, 28)
plt.imshow(digit, cmap=plt.cm.binary)
plt.title(f"Ví dụ tập train - Nhãn thật: {train_labels[100]}")
plt.axis('off')
plt.show()
network.save("mnist_model.keras")
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.8529 - loss: 0.4660 - val_accuracy: 0.9625 - val_loss: 0.1142
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9630 - loss: 0.1183 - val_accuracy: 0.9772 - val_loss: 0.0743
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9749 - loss: 0.0774 - val_accuracy: 0.9778 - val_loss: 0.0714
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9811 - loss: 0.0624 - val_accuracy: 0.9770 - val_loss: 0.0751
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9845 - loss: 0.0483 - val_accuracy: 0.9788 - val_loss: 0.0749
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9874 - loss: 0.0407 - val_accuracy: 0.9813 - val_loss: 0.0666
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9901 - loss: 0.0328 - val_accuracy: 0.9803 - val_loss: 0.0662
# Epoch 8/100
# ...

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import Dropout


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images.reshape(60000, 28*28).astype('float32') / 255
test_images = test_images.reshape(10000, 784).astype('float32') / 255

train_labels_cat = to_categorical(train_labels)
test_labels_cat = to_categorical(test_labels)


network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(784,)))
network.add(Dropout(0.2))
network.add(layers.Dense(256, activation='relu'))
network.add(Dropout(0.2))
network.add(layers.Dense(10, activation='softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_images, train_labels_cat,
                      epochs=100,
                      batch_size=128,
                      validation_data=(test_images, test_labels_cat))


test_loss, test_acc = network.evaluate(test_images, test_labels_cat)
print(' Test accuracy:', test_acc)


img_path = '/content/drive/MyDrive/digit/1.png'
img = load_img(img_path, color_mode='grayscale', target_size=(28, 28))
img = img_to_array(img)
img = img.astype('float32') / 255.0
img = img.reshape(1, 784)

pred = network.predict(img)
predicted_digit = np.argmax(pred)

print(" Dự đoán ảnh từ file là:", predicted_digit)
plt.imshow(img.reshape(28, 28), cmap='gray')
plt.title(f"Dự đoán: {predicted_digit}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.8554 - loss: 0.4649 - val_accuracy: 0.9617 - val_loss: 0.1177
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9635 - loss: 0.1196 - val_accuracy: 0.9698 - val_loss: 0.1025
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9740 - loss: 0.0817 - val_accuracy: 0.9772 - val_loss: 0.0716
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9805 - loss: 0.0641 - val_accuracy: 0.9776 - val_loss: 0.0723
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9839 - loss: 0.0505 - val_accuracy: 0.9805 - val_loss: 0.0661
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9862 - loss: 0.0427 - val_accuracy: 0.9834 - val_loss: 0.0555
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9890 - loss: 0.0358 - val_accuracy: 0.9840 - val_loss: 0.0602
# Epoch 8/100
# ...

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images.reshape(60000, 28*28).astype('float32') / 255
test_images = test_images.reshape(10000, 784).astype('float32') / 255

train_labels_cat = to_categorical(train_labels)
test_labels_cat = to_categorical(test_labels)


network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(784,)))
network.add(Dropout(0.2))
network.add(layers.Dense(256, activation='relu'))
network.add(Dropout(0.2))
network.add(layers.Dense(10, activation='softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_images, train_labels_cat,
                      epochs=100,
                      batch_size=128,
                      validation_data=(test_images, test_labels_cat))


test_loss, test_acc = network.evaluate(test_images, test_labels_cat)
print(' Test accuracy:', test_acc)


img_path = '/content/drive/MyDrive/digit/2.png'
img = load_img(img_path, color_mode='grayscale', target_size=(28, 28))
img = img_to_array(img)
img = img.astype('float32') / 255.0
img = img.reshape(1, 784)

pred = network.predict(img)
predicted_digit = np.argmax(pred)

print(" Dự đoán ảnh từ file là:", predicted_digit)

digit = train_images[100].reshape(28, 28)
plt.imshow(digit, cmap=plt.cm.binary)
plt.title(f"Ví dụ tập train - Nhãn thật: {train_labels[100]}")
plt.axis('off')
plt.show()
network.save("mnist_model.keras")
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8558 - loss: 0.4660 - val_accuracy: 0.9656 - val_loss: 0.1086
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9637 - loss: 0.1186 - val_accuracy: 0.9772 - val_loss: 0.0766
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.9764 - loss: 0.0789 - val_accuracy: 0.9795 - val_loss: 0.0697
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.9810 - loss: 0.0603 - val_accuracy: 0.9804 - val_loss: 0.0690
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.9845 - loss: 0.0487 - val_accuracy: 0.9778 - val_loss: 0.0751
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9871 - loss: 0.0398 - val_accuracy: 0.9822 - val_loss: 0.0635
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9887 - loss: 0.0363 - val_accuracy: 0.9814 - val_loss: 0.0764
# Epoch 8/100
# ...

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import Dropout


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images.reshape(60000, 28*28).astype('float32') / 255
test_images = test_images.reshape(10000, 784).astype('float32') / 255

train_labels_cat = to_categorical(train_labels)
test_labels_cat = to_categorical(test_labels)


network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(784,)))
network.add(Dropout(0.2))
network.add(layers.Dense(256, activation='relu'))
network.add(Dropout(0.2))
network.add(layers.Dense(10, activation='softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_images, train_labels_cat,
                      epochs=100,
                      batch_size=128,
                      validation_data=(test_images, test_labels_cat))


test_loss, test_acc = network.evaluate(test_images, test_labels_cat)
print(' Test accuracy:', test_acc)


img_path = '/content/drive/MyDrive/digit/3.webp'
img = load_img(img_path, color_mode='grayscale', target_size=(28, 28))
img = img_to_array(img)
img = img.astype('float32') / 255.0
img = img.reshape(1, 784)

pred = network.predict(img)
predicted_digit = np.argmax(pred)

print(" Dự đoán ảnh từ file là:", predicted_digit)
plt.imshow(img.reshape(28, 28), cmap='gray')
plt.title(f"Dự đoán: {predicted_digit}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.8594 - loss: 0.4625 - val_accuracy: 0.9603 - val_loss: 0.1232
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9639 - loss: 0.1161 - val_accuracy: 0.9755 - val_loss: 0.0804
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.9767 - loss: 0.0764 - val_accuracy: 0.9760 - val_loss: 0.0770
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9811 - loss: 0.0585 - val_accuracy: 0.9807 - val_loss: 0.0637
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9847 - loss: 0.0462 - val_accuracy: 0.9797 - val_loss: 0.0699
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.9870 - loss: 0.0428 - val_accuracy: 0.9801 - val_loss: 0.0717
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.9884 - loss: 0.0344 - val_accuracy: 0.9832 - val_loss: 0.0633
# Epoch 8/100
# ...

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import Dropout


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images.reshape(60000, 28*28).astype('float32') / 255
test_images = test_images.reshape(10000, 784).astype('float32') / 255

train_labels_cat = to_categorical(train_labels)
test_labels_cat = to_categorical(test_labels)


network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(784,)))
network.add(Dropout(0.2))
network.add(layers.Dense(256, activation='relu'))
network.add(Dropout(0.2))
network.add(layers.Dense(10, activation='softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_images, train_labels_cat,
                      epochs=100,
                      batch_size=128,
                      validation_data=(test_images, test_labels_cat))


test_loss, test_acc = network.evaluate(test_images, test_labels_cat)
print(' Test accuracy:', test_acc)


img_path = '/content/drive/MyDrive/digit/4.png'
img = load_img(img_path, color_mode='grayscale', target_size=(28, 28))
img = img_to_array(img)
img = img.astype('float32') / 255.0
img = img.reshape(1, 784)

pred = network.predict(img)
predicted_digit = np.argmax(pred)

print(" Dự đoán ảnh từ file là:", predicted_digit)
plt.imshow(img.reshape(28, 28), cmap='gray')
plt.title(f"Dự đoán: {predicted_digit}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.8560 - loss: 0.4679 - val_accuracy: 0.9671 - val_loss: 0.1060
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9641 - loss: 0.1161 - val_accuracy: 0.9734 - val_loss: 0.0828
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9760 - loss: 0.0786 - val_accuracy: 0.9756 - val_loss: 0.0807
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.9806 - loss: 0.0634 - val_accuracy: 0.9798 - val_loss: 0.0654
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.9837 - loss: 0.0493 - val_accuracy: 0.9796 - val_loss: 0.0712
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.9878 - loss: 0.0397 - val_accuracy: 0.9819 - val_loss: 0.0657
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.9889 - loss: 0.0350 - val_accuracy: 0.9814 - val_loss: 0.0667
# Epoch 8/100
# ...

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import Dropout


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images.reshape(60000, 28*28).astype('float32') / 255
test_images = test_images.reshape(10000, 784).astype('float32') / 255

train_labels_cat = to_categorical(train_labels)
test_labels_cat = to_categorical(test_labels)


network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(784,)))
network.add(Dropout(0.2))
network.add(layers.Dense(256, activation='relu'))
network.add(Dropout(0.2))
network.add(layers.Dense(10, activation='softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_images, train_labels_cat,
                      epochs=100,
                      batch_size=128,
                      validation_data=(test_images, test_labels_cat))


test_loss, test_acc = network.evaluate(test_images, test_labels_cat)
print(' Test accuracy:', test_acc)


img_path = '/content/drive/MyDrive/digit/5.png'
img = load_img(img_path, color_mode='grayscale', target_size=(28, 28))
img = img_to_array(img)
img = img.astype('float32') / 255.0
img = img.reshape(1, 784)

pred = network.predict(img)
predicted_digit = np.argmax(pred)

print(" Dự đoán ảnh từ file là:", predicted_digit)
plt.imshow(img.reshape(28, 28), cmap='gray')
plt.title(f"Dự đoán: {predicted_digit}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.8526 - loss: 0.4719 - val_accuracy: 0.9643 - val_loss: 0.1142
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9654 - loss: 0.1163 - val_accuracy: 0.9715 - val_loss: 0.0875
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.9743 - loss: 0.0794 - val_accuracy: 0.9789 - val_loss: 0.0676
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.9809 - loss: 0.0606 - val_accuracy: 0.9802 - val_loss: 0.0648
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9849 - loss: 0.0477 - val_accuracy: 0.9811 - val_loss: 0.0672
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9881 - loss: 0.0376 - val_accuracy: 0.9814 - val_loss: 0.0647
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9888 - loss: 0.0347 - val_accuracy: 0.9826 - val_loss: 0.0634
# Epoch 8/100
# ...

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import Dropout


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images.reshape(60000, 28*28).astype('float32') / 255
test_images = test_images.reshape(10000, 784).astype('float32') / 255

train_labels_cat = to_categorical(train_labels)
test_labels_cat = to_categorical(test_labels)


network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(784,)))
network.add(Dropout(0.2))
network.add(layers.Dense(256, activation='relu'))
network.add(Dropout(0.2))
network.add(layers.Dense(10, activation='softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_images, train_labels_cat,
                      epochs=100,
                      batch_size=128,
                      validation_data=(test_images, test_labels_cat))


test_loss, test_acc = network.evaluate(test_images, test_labels_cat)
print(' Test accuracy:', test_acc)


img_path = '/content/drive/MyDrive/digit/6.png'
img = load_img(img_path, color_mode='grayscale', target_size=(28, 28))
img = img_to_array(img)
img = img.astype('float32') / 255.0
img = img.reshape(1, 784)

pred = network.predict(img)
predicted_digit = np.argmax(pred)

print(" Dự đoán ảnh từ file là:", predicted_digit)
plt.imshow(img.reshape(28, 28), cmap='gray')
plt.title(f"Dự đoán: {predicted_digit}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.8578 - loss: 0.4595 - val_accuracy: 0.9644 - val_loss: 0.1144
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.9653 - loss: 0.1140 - val_accuracy: 0.9751 - val_loss: 0.0790
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9768 - loss: 0.0753 - val_accuracy: 0.9749 - val_loss: 0.0743
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9818 - loss: 0.0582 - val_accuracy: 0.9823 - val_loss: 0.0596
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9851 - loss: 0.0479 - val_accuracy: 0.9797 - val_loss: 0.0691
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9881 - loss: 0.0384 - val_accuracy: 0.9807 - val_loss: 0.0690
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9888 - loss: 0.0344 - val_accuracy: 0.9830 - val_loss: 0.0604
# Epoch 8/100
# ...

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import Dropout


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images.reshape(60000, 28*28).astype('float32') / 255
test_images = test_images.reshape(10000, 784).astype('float32') / 255

train_labels_cat = to_categorical(train_labels)
test_labels_cat = to_categorical(test_labels)


network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(784,)))
network.add(Dropout(0.2))
network.add(layers.Dense(256, activation='relu'))
network.add(Dropout(0.2))
network.add(layers.Dense(10, activation='softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_images, train_labels_cat,
                      epochs=100,
                      batch_size=128,
                      validation_data=(test_images, test_labels_cat))


test_loss, test_acc = network.evaluate(test_images, test_labels_cat)
print(' Test accuracy:', test_acc)


img_path = '/content/drive/MyDrive/digit/7.webp'
img = load_img(img_path, color_mode='grayscale', target_size=(28, 28))
img = img_to_array(img)
img = img.astype('float32') / 255.0
img = img.reshape(1, 784)

pred = network.predict(img)
predicted_digit = np.argmax(pred)

print(" Dự đoán ảnh từ file là:", predicted_digit)
plt.imshow(img.reshape(28, 28), cmap='gray')
plt.title(f"Dự đoán: {predicted_digit}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.8590 - loss: 0.4569 - val_accuracy: 0.9680 - val_loss: 0.1001
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9664 - loss: 0.1102 - val_accuracy: 0.9707 - val_loss: 0.0952
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9759 - loss: 0.0789 - val_accuracy: 0.9735 - val_loss: 0.0888
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9814 - loss: 0.0594 - val_accuracy: 0.9815 - val_loss: 0.0626
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9850 - loss: 0.0496 - val_accuracy: 0.9814 - val_loss: 0.0608
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9869 - loss: 0.0422 - val_accuracy: 0.9806 - val_loss: 0.0655
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.9897 - loss: 0.0330 - val_accuracy: 0.9808 - val_loss: 0.0687
# Epoch 8/100
# ...

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import Dropout


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images.reshape(60000, 28*28).astype('float32') / 255
test_images = test_images.reshape(10000, 784).astype('float32') / 255

train_labels_cat = to_categorical(train_labels)
test_labels_cat = to_categorical(test_labels)


network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(784,)))
network.add(Dropout(0.2))
network.add(layers.Dense(256, activation='relu'))
network.add(Dropout(0.2))
network.add(layers.Dense(10, activation='softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_images, train_labels_cat,
                      epochs=100,
                      batch_size=128,
                      validation_data=(test_images, test_labels_cat))


test_loss, test_acc = network.evaluate(test_images, test_labels_cat)
print(' Test accuracy:', test_acc)


img_path = '/content/drive/MyDrive/digit/8.png'
img = load_img(img_path, color_mode='grayscale', target_size=(28, 28))
img = img_to_array(img)
img = img.astype('float32') / 255.0
img = img.reshape(1, 784)

pred = network.predict(img)
predicted_digit = np.argmax(pred)

print(" Dự đoán ảnh từ file là:", predicted_digit)
plt.imshow(img.reshape(28, 28), cmap='gray')
plt.title(f"Dự đoán: {predicted_digit}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 18s 34ms/step - accuracy: 0.8557 - loss: 0.4630 - val_accuracy: 0.9540 - val_loss: 0.1466
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9644 - loss: 0.1149 - val_accuracy: 0.9726 - val_loss: 0.0865
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9764 - loss: 0.0765 - val_accuracy: 0.9774 - val_loss: 0.0700
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9822 - loss: 0.0574 - val_accuracy: 0.9774 - val_loss: 0.0756
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9851 - loss: 0.0493 - val_accuracy: 0.9813 - val_loss: 0.0644
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9875 - loss: 0.0411 - val_accuracy: 0.9828 - val_loss: 0.0571
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.9889 - loss: 0.0359 - val_accuracy: 0.9811 - val_loss: 0.0740
# Epoch 8/100
# ...

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import Dropout


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images.reshape(60000, 28*28).astype('float32') / 255
test_images = test_images.reshape(10000, 784).astype('float32') / 255

train_labels_cat = to_categorical(train_labels)
test_labels_cat = to_categorical(test_labels)


network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(784,)))
network.add(Dropout(0.2))
network.add(layers.Dense(256, activation='relu'))
network.add(Dropout(0.2))
network.add(layers.Dense(10, activation='softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_images, train_labels_cat,
                      epochs=100,
                      batch_size=128,
                      validation_data=(test_images, test_labels_cat))


test_loss, test_acc = network.evaluate(test_images, test_labels_cat)
print(' Test accuracy:', test_acc)


img_path ='/content/drive/MyDrive/digit/9.png'
img = load_img(img_path, color_mode='grayscale', target_size=(28, 28))
img = img_to_array(img)
img = img.astype('float32') / 255.0
img = img.reshape(1, 784)

pred = network.predict(img)
predicted_digit = np.argmax(pred)

print(" Dự đoán ảnh từ file là:", predicted_digit)
plt.imshow(img.reshape(28, 28), cmap='gray')
plt.title(f"Dự đoán: {predicted_digit}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.8542 - loss: 0.4629 - val_accuracy: 0.9553 - val_loss: 0.1389
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.9647 - loss: 0.1154 - val_accuracy: 0.9736 - val_loss: 0.0839
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9753 - loss: 0.0789 - val_accuracy: 0.9775 - val_loss: 0.0726
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9805 - loss: 0.0613 - val_accuracy: 0.9804 - val_loss: 0.0693
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.9831 - loss: 0.0512 - val_accuracy: 0.9811 - val_loss: 0.0683
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.9876 - loss: 0.0387 - val_accuracy: 0.9837 - val_loss: 0.0611
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.9883 - loss: 0.0357 - val_accuracy: 0.9818 - val_loss: 0.0654
# Epoch 8/100
# ...

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import Dropout


(train_images, train_labels), (test_images, test_labels) = mnist.load_data()


train_images = train_images.reshape(60000, 28*28).astype('float32') / 255
test_images = test_images.reshape(10000, 784).astype('float32') / 255

train_labels_cat = to_categorical(train_labels)
test_labels_cat = to_categorical(test_labels)


network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(784,)))
network.add(Dropout(0.2))
network.add(layers.Dense(256, activation='relu'))
network.add(Dropout(0.2))
network.add(layers.Dense(10, activation='softmax'))


network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

history = network.fit(train_images, train_labels_cat,
                      epochs=100,
                      batch_size=128,
                      validation_data=(test_images, test_labels_cat))


test_loss, test_acc = network.evaluate(test_images, test_labels_cat)
print(' Test accuracy:', test_acc)


img_path ='/content/drive/MyDrive/digit/0.png'
img = load_img(img_path, color_mode='grayscale', target_size=(28, 28))
img = img_to_array(img)
img = img.astype('float32') / 255.0
img = img.reshape(1, 784)

pred = network.predict(img)
predicted_digit = np.argmax(pred)

print(" Dự đoán ảnh từ file là:", predicted_digit)
plt.imshow(img.reshape(28, 28), cmap='gray')
plt.title(f"Dự đoán: {predicted_digit}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - accuracy: 0.8559 - loss: 0.4675 - val_accuracy: 0.9606 - val_loss: 0.1226
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9647 - loss: 0.1145 - val_accuracy: 0.9767 - val_loss: 0.0737
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9771 - loss: 0.0750 - val_accuracy: 0.9746 - val_loss: 0.0805
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.9804 - loss: 0.0639 - val_accuracy: 0.9799 - val_loss: 0.0715
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.9850 - loss: 0.0475 - val_accuracy: 0.9831 - val_loss: 0.0559
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9872 - loss: 0.0403 - val_accuracy: 0.9796 - val_loss: 0.0712
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.9893 - loss: 0.0342 - val_accuracy: 0.9830 - val_loss: 0.0605
# Epoch 8/100
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/mnhtm187/Minh-T-m-31241027094/blob/main/TEAM_TASK_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator


data_dir = '/content/drive/MyDrive/Images_CNN'
img_width, img_height = 128, 128
batch_size = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    zoom_range=0.3,
    shear_range=0.3,
    horizontal_flip=True,
    fill_mode='nearest'
)
train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode="categorical",
    subset="training"  # Tập huấn luyện
)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset="validation"  # Tập xác thực
)

# Mục chứa không xác định được có bao nhiêu lớp nên để số tự động
num_classes = train_generator.num_classes

model = Sequential([
    Conv2D(32, (3,3), activation="relu", input_shape=(128, 128, 3)),
    Conv2D(32, (3,3), activation="relu"),
    MaxPooling2D(2,2),
    Dropout(0.25),

    Conv2D(64, (3,3), activation="relu"),
    Conv2D(64, (3,3), activation="relu"),
    MaxPooling2D(2,2),
    Dropout(0.3),

    Flatten(),
    Dense(512, activation="relu"),
    Dropout(0.5),
    Dense(num_classes, activation="softmax")
])

model.compile(optimizer="adam",
              loss="categorical_crossentropy",
              metrics=["accuracy"])

history = model.fit(
    train_generator,
    epochs=30,
    validation_data=validation_generator
)

model.summary()

plt.plot(history.history['accuracy'], label = "Kết quả huấn luyện")
plt.plot(history.history['val_accuracy'], label="Độ chính xác xác thực")
plt.xlabel("Số lần học (epoch)")
plt.ylabel("Độ chính xác")
plt.legend()
plt.show()
# Out:
# Found 276 images belonging to 22 classes.
# Found 58 images belonging to 22 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 120s 13s/step - accuracy: 0.0515 - loss: 3.8682 - val_accuracy: 0.0517 - val_loss: 3.0858
# Epoch 2/30
# ...

# %%
from keras.utils import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt


image_path = "/content/drive/MyDrive/Images_CNN/Thừa Thiên Huế/Món_ăn_Bún hến.jpg"

img = load_img(image_path, target_size=(128, 128))
plt.imshow(img)
plt.axis('off')
plt.title("Ảnh cần nhận dạng")
plt.show()

img_array = img_to_array(img)
img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)
pred = model.predict(img_array)
predicted_index = np.argmax(pred)
class_labels = {v: k for k, v in train_generator.class_indices.items()}
predicted_province = class_labels[predicted_index]

print(f" Dự đoán ảnh thuộc tỉnh/thành: {predicted_province}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#  Dự đoán ảnh thuộc tỉnh/thành: Thừa Thiên Huế

# %%
from keras.utils import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt


image_path = "/content/drive/MyDrive/Images_CNN/Thừa Thiên Huế/Tham_quan_Chợ Đông Ba.jpg"

img = load_img(image_path, target_size=(128, 128))
plt.imshow(img)
plt.axis('off')
plt.title("Ảnh cần nhận dạng")
plt.show()

img_array = img_to_array(img)
img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)
pred = model.predict(img_array)
predicted_index = np.argmax(pred)
class_labels = {v: k for k, v in train_generator.class_indices.items()}
predicted_province = class_labels[predicted_index]

print(f" Dự đoán ảnh thuộc tỉnh/thành: {predicted_province}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
#  Dự đoán ảnh thuộc tỉnh/thành: Thừa Thiên Huế

# %%
from keras.utils import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt


image_path = "/content/drive/MyDrive/Images_CNN/Khánh Hoà/Tham_quan_Vịnh Vân Phong.jpg"

img = load_img(image_path, target_size=(128, 128))
plt.imshow(img)
plt.axis('off')
plt.title("Ảnh cần nhận dạng")
plt.show()

img_array = img_to_array(img)
img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)
pred = model.predict(img_array)
predicted_index = np.argmax(pred)
class_labels = {v: k for k, v in train_generator.class_indices.items()}
predicted_province = class_labels[predicted_index]

print(f" Dự đoán ảnh thuộc tỉnh/thành: {predicted_province}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
#  Dự đoán ảnh thuộc tỉnh/thành: Phú Yên

# %%
from keras.utils import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt


image_path = "/content/drive/MyDrive/Images_CNN/Khánh Hoà/Món_ăn_Nhum Khánh Hoà.jpg"

img = load_img(image_path, target_size=(128, 128))
plt.imshow(img)
plt.axis('off')
plt.title("Ảnh cần nhận dạng")
plt.show()

img_array = img_to_array(img)
img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)
pred = model.predict(img_array)
predicted_index = np.argmax(pred)
class_labels = {v: k for k, v in train_generator.class_indices.items()}
predicted_province = class_labels[predicted_index]

print(f" Dự đoán ảnh thuộc tỉnh/thành: {predicted_province}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
#  Dự đoán ảnh thuộc tỉnh/thành: Khánh Hoà

# %%
from keras.utils import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt


image_path = "/content/drive/MyDrive/Images_CNN/Phú Yên/Tham_quan_Đầm Ô Loan.jpg"

img = load_img(image_path, target_size=(128, 128))
plt.imshow(img)
plt.axis('off')
plt.title("Ảnh cần nhận dạng")
plt.show()

img_array = img_to_array(img)
img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)
pred = model.predict(img_array)
predicted_index = np.argmax(pred)
class_labels = {v: k for k, v in train_generator.class_indices.items()}
predicted_province = class_labels[predicted_index]

print(f" Dự đoán ảnh thuộc tỉnh/thành: {predicted_province}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
#  Dự đoán ảnh thuộc tỉnh/thành: Phú Yên

# %%
from keras.utils import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt


image_path = "/content/drive/MyDrive/Images_CNN/Hà Giang/Món_ăn_Phở chua Hà Giang.jpeg"

img = load_img(image_path, target_size=(128, 128))
plt.imshow(img)
plt.axis('off')
plt.title("Ảnh cần nhận dạng")
plt.show()

img_array = img_to_array(img)
img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)
pred = model.predict(img_array)
predicted_index = np.argmax(pred)
class_labels = {v: k for k, v in train_generator.class_indices.items()}
predicted_province = class_labels[predicted_index]

print(f" Dự đoán ảnh thuộc tỉnh/thành: {predicted_province}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
#  Dự đoán ảnh thuộc tỉnh/thành: Khánh Hoà

# %%
from keras.utils import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt


image_path = "/content/drive/MyDrive/Images_CNN/Hà Giang/Tham_quan_Hoàng Su Phì.jpg"

img = load_img(image_path, target_size=(128, 128))
plt.imshow(img)
plt.axis('off')
plt.title("Ảnh cần nhận dạng")
plt.show()

img_array = img_to_array(img)
img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)
pred = model.predict(img_array)
predicted_index = np.argmax(pred)
class_labels = {v: k for k, v in train_generator.class_indices.items()}
predicted_province = class_labels[predicted_index]

print(f" Dự đoán ảnh thuộc tỉnh/thành: {predicted_province}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
#  Dự đoán ảnh thuộc tỉnh/thành: Hà Giang

# %%
from keras.utils import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt


image_path = "/content/drive/MyDrive/Images_CNN/Hà Giang/Tham_quan_Lũng Táo.jpg"

img = load_img(image_path, target_size=(128, 128))
plt.imshow(img)
plt.axis('off')
plt.title("Ảnh cần nhận dạng")
plt.show()

img_array = img_to_array(img)
img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)
pred = model.predict(img_array)
predicted_index = np.argmax(pred)
class_labels = {v: k for k, v in train_generator.class_indices.items()}
predicted_province = class_labels[predicted_index]

print(f" Dự đoán ảnh thuộc tỉnh/thành: {predicted_province}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
#  Dự đoán ảnh thuộc tỉnh/thành: Hà Giang

# %%
from keras.utils import load_img, img_to_array
import numpy as np
import matplotlib.pyplot as plt


image_path = "/content/drive/MyDrive/Images_CNN/Bắc Ninh/Tham_quan_Thành cổ Luy Lâu.webp"

img = load_img(image_path, target_size=(128, 128))
plt.imshow(img)
plt.axis('off')
plt.title("Ảnh cần nhận dạng")
plt.show()

img_array = img_to_array(img)
img_array = img_array / 255.0
img_array = np.expand_dims(img_array, axis=0)
pred = model.predict(img_array)
predicted_index = np.argmax(pred)
class_labels = {v: k for k, v in train_generator.class_indices.items()}
predicted_province = class_labels[predicted_index]

print(f" Dự đoán ảnh thuộc tỉnh/thành: {predicted_province}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
#  Dự đoán ảnh thuộc tỉnh/thành: Quảng Ninh

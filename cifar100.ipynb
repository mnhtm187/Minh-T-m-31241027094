# %% [markdown]
# <a href="https://colab.research.google.com/github/mnhtm187/Minh-T-m-31241027094/blob/main/cifar100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.reshape(50000, 32 * 32 * 3).astype('float32') / 255.0
x_test = x_test.reshape(10000, 32 * 32 * 3).astype('float32') / 255.0

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(100, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=400,
                    validation_data=(x_test, y_test))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Độ chính xác :", test_acc)

img_path = '/content/drive/MyDrive/cifar/chair.webp'
img = load_img(img_path, target_size=(32, 32))
img = img_to_array(img).astype('float32') / 255.0
img = img.reshape(1, 32 * 32 * 3)

prediction = model.predict(img)
predicted_label = np.argmax(prediction)
label_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]

print("Ảnh được dự đoán là:", label_names[predicted_label])

plt.imshow(img.reshape(32, 32, 3))
plt.title(f"Dự đoán: {label_names[predicted_label]}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 30s 225ms/step - accuracy: 0.0127 - loss: 4.6724 - val_accuracy: 0.0423 - val_loss: 4.2731
# Epoch 2/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 32s 259ms/step - accuracy: 0.0389 - loss: 4.3088 - val_accuracy: 0.0713 - val_loss: 4.0977
# Epoch 3/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 37s 225ms/step - accuracy: 0.0525 - loss: 4.1700 - val_accuracy: 0.0834 - val_loss: 4.0428
# Epoch 4/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 216ms/step - accuracy: 0.0608 - loss: 4.1206 - val_accuracy: 0.0972 - val_loss: 3.9673
# Epoch 5/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 221ms/step - accuracy: 0.0720 - loss: 4.0428 - val_accuracy: 0.1062 - val_loss: 3.8836
# Epoch 6/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 27s 213ms/step - accuracy: 0.0808 - loss: 3.9776 - val_accuracy: 0.1220 - val_loss: 3.8508
# Epoch 7/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 216ms/step - accuracy: 0.0839 - loss: 3.9441 - val_accuracy: 0.1202 - val_loss: 3.8490
# Epoch 8/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 215ms/step - accuracy: 0.0892 - loss: 3.9109 - val_accuracy: 0.1276 - val_loss: 3.8291
# Epoch 9/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 214ms/step - accuracy: 0.0967 - loss: 3.8820 - val_accuracy: 0.1398 - val_loss: 3.7898
# Epoch 10/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 225ms/step - accuracy: 0.1005 - loss: 3.8562 - val_accuracy: 0.1435 - val_loss: 3.7700
# Epoch 11/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 225ms/step - accuracy: 0.1009 - loss: 3.8607 - val_accuracy: 0.1418 - val_loss: 3.7740
# Epoch 12/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 27s 217ms/step - accuracy: 0.1055 - loss: 3.8317 - val_accuracy: 0.1441 - val_loss: 3.7568
# Epoch 13/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 207ms/step - accuracy: 0.1072 - loss: 3.8070 - val_accuracy: 0.1461 - val_loss: 3.7621
# Epoch 14/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 27s 217ms/step - accuracy: 0.1102 - loss: 3.7895 - val_accuracy: 0.1472 - val_loss: 3.7351
# Epoch 15/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 224ms/step - accuracy: 0.1116 - loss: 3.7792 - val_accuracy: 0.1473 - val_loss: 3.7329
# Epoch 16/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 28s 225ms/step - accuracy: 0.1143 - loss: 3.7585 - val_accuracy: 0.1452 - val_loss: 3.7193
# Epoch 17/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 221ms/step - accuracy: 0.1138 - loss: 3.7538 - val_accuracy: 0.1437 - val_loss: 3.7384
# Epoch 18/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 231ms/step - accuracy: 0.1166 - loss: 3.7467 - val_accuracy: 0.1537 - val_loss: 3.6826
# Epoch 19/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.1192 - loss: 3.7145 - val_accuracy: 0.1597 - val_loss: 3.6769
# Epoch 20/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 210ms/step - accuracy: 0.1202 - loss: 3.7085 - val_accuracy: 0.1551 - val_loss: 3.6914
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.1515 - loss: 3.6967
# Độ chính xác : 0.1551000028848648
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Ảnh được dự đoán là: chair

# %%
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.reshape(50000, 32 * 32 * 3).astype('float32') / 255.0
x_test = x_test.reshape(10000, 32 * 32 * 3).astype('float32') / 255.0

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(100, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=128,
                    validation_data=(x_test, y_test))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Độ chính xác :", test_acc)

img_path = '/content/drive/MyDrive/cifar/bird.jpg'
img = load_img(img_path, target_size=(32, 32))
img = img_to_array(img).astype('float32') / 255.0
img = img.reshape(1, 32 * 32 * 3)

prediction = model.predict(img)
predicted_label = np.argmax(prediction)
label_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]

print("Ảnh được dự đoán là:", label_names[predicted_label])

plt.imshow(img.reshape(32, 32, 3))
plt.title(f"Dự đoán: {label_names[predicted_label]}")
plt.axis('off')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 94ms/step - accuracy: 0.0151 - loss: 4.6380 - val_accuracy: 0.0568 - val_loss: 4.2148
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.0396 - loss: 4.2851 - val_accuracy: 0.0746 - val_loss: 4.1150
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 93ms/step - accuracy: 0.0476 - loss: 4.1745 - val_accuracy: 0.0760 - val_loss: 4.0967
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - accuracy: 0.0588 - loss: 4.1190 - val_accuracy: 0.0916 - val_loss: 4.0518
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - accuracy: 0.0612 - loss: 4.0990 - val_accuracy: 0.0808 - val_loss: 4.0545
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - accuracy: 0.0674 - loss: 4.0553 - val_accuracy: 0.0991 - val_loss: 4.0068
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 36s 93ms/step - accuracy: 0.0708 - loss: 4.0397 - val_accuracy: 0.0964 - val_loss: 3.9701
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 36s 91ms/step - accuracy: 0.0711 - loss: 4.0286 - val_accuracy: 0.1049 - val_loss: 3.9672
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 36s 93ms/step - accuracy: 0.0793 - loss: 3.9874 - val_accuracy: 0.0977 - val_loss: 3.9561
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 93ms/step - accuracy: 0.0799 - loss: 3.9824 - val_accuracy: 0.1086 - val_loss: 3.9304
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 93ms/step - accuracy: 0.0803 - loss: 3.9681 - val_accuracy: 0.1031 - val_loss: 3.9471
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - accuracy: 0.0835 - loss: 3.9610 - val_accuracy: 0.0965 - val_loss: 3.9432
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 91ms/step - accuracy: 0.0821 - loss: 3.9586 - val_accuracy: 0.1080 - val_loss: 3.9028
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 36s 93ms/step - accuracy: 0.0874 - loss: 3.9437 - val_accuracy: 0.1091 - val_loss: 3.8915
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 36s 92ms/step - accuracy: 0.0867 - loss: 3.9333 - val_accuracy: 0.1067 - val_loss: 3.8944
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 92ms/step - accuracy: 0.0855 - loss: 3.9368 - val_accuracy: 0.1032 - val_loss: 3.9246
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 94ms/step - accuracy: 0.0885 - loss: 3.9274 - val_accuracy: 0.1087 - val_loss: 3.9045
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 107ms/step - accuracy: 0.0899 - loss: 3.9110 - val_accuracy: 0.1103 - val_loss: 3.8717
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 79s 98ms/step - accuracy: 0.0898 - loss: 3.9083 - val_accuracy: 0.1072 - val_loss: 3.8861
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 36s 91ms/step - accuracy: 0.0913 - loss: 3.8973 - val_accuracy: 0.1137 - val_loss: 3.8687
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.1116 - loss: 3.8687
# Độ chính xác : 0.1137000024318695
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Ảnh được dự đoán là: crocodile

# %%
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.reshape(50000, 32 * 32 * 3).astype('float32') / 255.0
x_test = x_test.reshape(10000, 32 * 32 * 3).astype('float32') / 255.0

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(100, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=500,
                    validation_data=(x_test, y_test))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Độ chính xác :", test_acc)

img_path = '/content/drive/MyDrive/cifar/sunflower.jpg'
img = load_img(img_path, target_size=(32, 32))
img = img_to_array(img).astype('float32') / 255.0
img = img.reshape(1, 32 * 32 * 3)

prediction = model.predict(img)
predicted_label = np.argmax(prediction)
label_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]

print("Ảnh được dự đoán là:", label_names[predicted_label])

plt.imshow(img.reshape(32, 32, 3))
plt.title(f"Dự đoán: {label_names[predicted_label]}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 34s 319ms/step - accuracy: 0.0133 - loss: 4.6811 - val_accuracy: 0.0312 - val_loss: 4.3667
# Epoch 2/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 266ms/step - accuracy: 0.0330 - loss: 4.3598 - val_accuracy: 0.0657 - val_loss: 4.1263
# Epoch 3/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 43s 285ms/step - accuracy: 0.0490 - loss: 4.2068 - val_accuracy: 0.0850 - val_loss: 4.0248
# Epoch 4/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 253ms/step - accuracy: 0.0597 - loss: 4.1136 - val_accuracy: 0.0959 - val_loss: 3.9695
# Epoch 5/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 253ms/step - accuracy: 0.0708 - loss: 4.0509 - val_accuracy: 0.1152 - val_loss: 3.8861
# Epoch 6/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 255ms/step - accuracy: 0.0790 - loss: 3.9825 - val_accuracy: 0.1199 - val_loss: 3.8697
# Epoch 7/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - accuracy: 0.0843 - loss: 3.9543 - val_accuracy: 0.1250 - val_loss: 3.8629
# Epoch 8/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 42s 253ms/step - accuracy: 0.0878 - loss: 3.9230 - val_accuracy: 0.1285 - val_loss: 3.8082
# Epoch 9/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - accuracy: 0.0978 - loss: 3.8720 - val_accuracy: 0.1336 - val_loss: 3.7902
# Epoch 10/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 262ms/step - accuracy: 0.1023 - loss: 3.8523 - val_accuracy: 0.1347 - val_loss: 3.7575
# Epoch 11/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 266ms/step - accuracy: 0.0982 - loss: 3.8486 - val_accuracy: 0.1406 - val_loss: 3.7533
# Epoch 12/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 271ms/step - accuracy: 0.1066 - loss: 3.8141 - val_accuracy: 0.1428 - val_loss: 3.7442
# Epoch 13/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 270ms/step - accuracy: 0.1113 - loss: 3.8104 - val_accuracy: 0.1481 - val_loss: 3.7337
# Epoch 14/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 43s 294ms/step - accuracy: 0.1114 - loss: 3.7815 - val_accuracy: 0.1470 - val_loss: 3.7392
# Epoch 15/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 37s 255ms/step - accuracy: 0.1152 - loss: 3.7714 - val_accuracy: 0.1473 - val_loss: 3.7254
# Epoch 16/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 250ms/step - accuracy: 0.1181 - loss: 3.7382 - val_accuracy: 0.1532 - val_loss: 3.6938
# Epoch 17/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 248ms/step - accuracy: 0.1202 - loss: 3.7478 - val_accuracy: 0.1537 - val_loss: 3.6837
# Epoch 18/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 253ms/step - accuracy: 0.1186 - loss: 3.7374 - val_accuracy: 0.1546 - val_loss: 3.6940
# Epoch 19/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - accuracy: 0.1245 - loss: 3.7070 - val_accuracy: 0.1581 - val_loss: 3.6645
# Epoch 20/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 249ms/step - accuracy: 0.1249 - loss: 3.7004 - val_accuracy: 0.1572 - val_loss: 3.6683
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.1584 - loss: 3.6699
# Độ chính xác : 0.15719999372959137
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# Ảnh được dự đoán là: sunflower

# %%
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.reshape(50000, 32 * 32 * 3).astype('float32') / 255.0
x_test = x_test.reshape(10000, 32 * 32 * 3).astype('float32') / 255.0

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(100, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=128,
                    validation_data=(x_test, y_test))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Độ chính xác :", test_acc)

img_path = '/content/drive/MyDrive/cifar/imagecua.jpg'
img = load_img(img_path, target_size=(32, 32))
img = img_to_array(img).astype('float32') / 255.0
img = img.reshape(1, 32 * 32 * 3)

prediction = model.predict(img)
predicted_label = np.argmax(prediction)
label_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]

print("Ảnh được dự đoán là:", label_names[predicted_label])

plt.imshow(img.reshape(32, 32, 3))
plt.title(f"Dự đoán: {label_names[predicted_label]}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 34s 52ms/step - accuracy: 0.0139 - loss: 4.6612 - val_accuracy: 0.0458 - val_loss: 4.2928
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.0339 - loss: 4.3136 - val_accuracy: 0.0601 - val_loss: 4.1419
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.0447 - loss: 4.2102 - val_accuracy: 0.0774 - val_loss: 4.0925
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.0508 - loss: 4.1582 - val_accuracy: 0.0764 - val_loss: 4.1139
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.0562 - loss: 4.1310 - val_accuracy: 0.0832 - val_loss: 4.0258
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.0577 - loss: 4.0920 - val_accuracy: 0.0862 - val_loss: 4.0296
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.0618 - loss: 4.0764 - val_accuracy: 0.0876 - val_loss: 3.9998
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.0662 - loss: 4.0612 - val_accuracy: 0.0937 - val_loss: 3.9959
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.0721 - loss: 4.0397 - val_accuracy: 0.0979 - val_loss: 3.9784
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.0703 - loss: 4.0427 - val_accuracy: 0.0849 - val_loss: 4.0191
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.0727 - loss: 4.0277 - val_accuracy: 0.0884 - val_loss: 3.9705
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.0758 - loss: 4.0020 - val_accuracy: 0.0906 - val_loss: 3.9862
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.0782 - loss: 3.9842 - val_accuracy: 0.0939 - val_loss: 3.9427
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.0797 - loss: 3.9782 - val_accuracy: 0.1008 - val_loss: 3.9239
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.0805 - loss: 3.9669 - val_accuracy: 0.0941 - val_loss: 3.9639
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 22s 54ms/step - accuracy: 0.0821 - loss: 3.9586 - val_accuracy: 0.1072 - val_loss: 3.9013
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.0814 - loss: 3.9488 - val_accuracy: 0.1032 - val_loss: 3.9207
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.0856 - loss: 3.9543 - val_accuracy: 0.1002 - val_loss: 3.9263
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.0880 - loss: 3.9314 - val_accuracy: 0.1039 - val_loss: 3.9027
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.0849 - loss: 3.9418 - val_accuracy: 0.1097 - val_loss: 3.8892
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.1072 - loss: 3.8929
# Độ chính xác : 0.10970000177621841
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Ảnh được dự đoán là: wardrobe

# %%
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.reshape(50000, 32 * 32 * 3).astype('float32') / 255.0
x_test = x_test.reshape(10000, 32 * 32 * 3).astype('float32') / 255.0

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(100, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=128,
                    validation_data=(x_test, y_test))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Độ chính xác :", test_acc)

img_path = '/content/drive/MyDrive/cifar/3AXCDNT-003_7a321a47-7272-44d2-a054-371548190a38.webp'
img = load_img(img_path, target_size=(32, 32))
img = img_to_array(img).astype('float32') / 255.0
img = img.reshape(1, 32 * 32 * 3)

prediction = model.predict(img)
predicted_label = np.argmax(prediction)
label_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]

print("Ảnh được dự đoán là:", label_names[predicted_label])

plt.imshow(img.reshape(32, 32, 3))
plt.title(f"Dự đoán: {label_names[predicted_label]}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.0153 - loss: 4.6394 - val_accuracy: 0.0518 - val_loss: 4.2090
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.0401 - loss: 4.2710 - val_accuracy: 0.0713 - val_loss: 4.1111
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.0503 - loss: 4.1697 - val_accuracy: 0.0794 - val_loss: 4.0475
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.0591 - loss: 4.1149 - val_accuracy: 0.0800 - val_loss: 4.0470
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - accuracy: 0.0646 - loss: 4.0818 - val_accuracy: 0.0920 - val_loss: 3.9988
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.0679 - loss: 4.0504 - val_accuracy: 0.0963 - val_loss: 4.0143
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.0741 - loss: 4.0294 - val_accuracy: 0.1006 - val_loss: 3.9604
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.0723 - loss: 4.0137 - val_accuracy: 0.1078 - val_loss: 3.9412
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.0789 - loss: 3.9866 - val_accuracy: 0.1011 - val_loss: 3.9509
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 22s 53ms/step - accuracy: 0.0801 - loss: 3.9766 - val_accuracy: 0.0998 - val_loss: 3.9319
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.0784 - loss: 3.9764 - val_accuracy: 0.0941 - val_loss: 3.9542
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.0797 - loss: 3.9698 - val_accuracy: 0.1009 - val_loss: 3.9334
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.0871 - loss: 3.9449 - val_accuracy: 0.1121 - val_loss: 3.8660
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.0911 - loss: 3.9284 - val_accuracy: 0.1027 - val_loss: 3.9088
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - accuracy: 0.0852 - loss: 3.9462 - val_accuracy: 0.0964 - val_loss: 3.9244
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - accuracy: 0.0899 - loss: 3.9264 - val_accuracy: 0.1057 - val_loss: 3.8767
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.0868 - loss: 3.9200 - val_accuracy: 0.1013 - val_loss: 3.9315
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.0876 - loss: 3.9196 - val_accuracy: 0.1045 - val_loss: 3.8965
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 21s 55ms/step - accuracy: 0.0881 - loss: 3.9128 - val_accuracy: 0.0988 - val_loss: 3.9081
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 20s 51ms/step - accuracy: 0.0904 - loss: 3.9011 - val_accuracy: 0.1115 - val_loss: 3.8675
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.1095 - loss: 3.8688
# Độ chính xác : 0.11150000244379044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Ảnh được dự đoán là: bicycle

# %%
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.reshape(50000, 32 * 32 * 3).astype('float32') / 255.0
x_test = x_test.reshape(10000, 32 * 32 * 3).astype('float32') / 255.0

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(100, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=128,
                    validation_data=(x_test, y_test))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Độ chính xác :", test_acc)

img_path = '/content/drive/MyDrive/cifar/550-cup.webp'
img = load_img(img_path, target_size=(32, 32))
img = img_to_array(img).astype('float32') / 255.0
img = img.reshape(1, 32 * 32 * 3)

prediction = model.predict(img)
predicted_label = np.argmax(prediction)
label_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]

print("Ảnh được dự đoán là:", label_names[predicted_label])

plt.imshow(img.reshape(32, 32, 3))
plt.title(f"Dự đoán: {label_names[predicted_label]}")
plt.axis('off')
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 10s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 103ms/step - accuracy: 0.0130 - loss: 4.6535 - val_accuracy: 0.0420 - val_loss: 4.3094
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 95ms/step - accuracy: 0.0353 - loss: 4.3186 - val_accuracy: 0.0646 - val_loss: 4.1462
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 98ms/step - accuracy: 0.0437 - loss: 4.2325 - val_accuracy: 0.0695 - val_loss: 4.1036
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - accuracy: 0.0511 - loss: 4.1589 - val_accuracy: 0.0818 - val_loss: 4.0725
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 100ms/step - accuracy: 0.0547 - loss: 4.1142 - val_accuracy: 0.0885 - val_loss: 4.0284
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 94ms/step - accuracy: 0.0651 - loss: 4.0703 - val_accuracy: 0.0938 - val_loss: 3.9783
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.0691 - loss: 4.0513 - val_accuracy: 0.0962 - val_loss: 3.9944
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 43s 102ms/step - accuracy: 0.0706 - loss: 4.0310 - val_accuracy: 0.1065 - val_loss: 3.9533
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 92ms/step - accuracy: 0.0767 - loss: 4.0007 - val_accuracy: 0.1001 - val_loss: 3.9586
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 94ms/step - accuracy: 0.0792 - loss: 3.9793 - val_accuracy: 0.1118 - val_loss: 3.9116
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 97ms/step - accuracy: 0.0806 - loss: 3.9710 - val_accuracy: 0.1016 - val_loss: 3.9221
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 94ms/step - accuracy: 0.0820 - loss: 3.9582 - val_accuracy: 0.1091 - val_loss: 3.9130
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.0824 - loss: 3.9559 - val_accuracy: 0.1050 - val_loss: 3.9304
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 93ms/step - accuracy: 0.0831 - loss: 3.9460 - val_accuracy: 0.1009 - val_loss: 3.9353
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 101ms/step - accuracy: 0.0839 - loss: 3.9344 - val_accuracy: 0.1115 - val_loss: 3.8808
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 94ms/step - accuracy: 0.0873 - loss: 3.9271 - val_accuracy: 0.1041 - val_loss: 3.9372
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.0897 - loss: 3.9120 - val_accuracy: 0.1132 - val_loss: 3.8557
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 95ms/step - accuracy: 0.0885 - loss: 3.9141 - val_accuracy: 0.1100 - val_loss: 3.8818
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 95ms/step - accuracy: 0.0899 - loss: 3.9072 - val_accuracy: 0.1090 - val_loss: 3.9046
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 93ms/step - accuracy: 0.0908 - loss: 3.9007 - val_accuracy: 0.1171 - val_loss: 3.8841
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.1143 - loss: 3.8853
# Độ chính xác : 0.11710000038146973
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Ảnh được dự đoán là: wardrobe

# %%
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.reshape(50000, 32 * 32 * 3).astype('float32') / 255.0
x_test = x_test.reshape(10000, 32 * 32 * 3).astype('float32') / 255.0

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(100, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=128,
                    validation_data=(x_test, y_test))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Độ chính xác :", test_acc)

img_path = '/content/drive/MyDrive/cifar/61tYXAy99IL.jpg'
img = load_img(img_path, target_size=(32, 32))
img = img_to_array(img).astype('float32') / 255.0
img = img.reshape(1, 32 * 32 * 3)

prediction = model.predict(img)
predicted_label = np.argmax(prediction)
label_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]

print("Ảnh được dự đoán là:", label_names[predicted_label])

plt.imshow(img.reshape(32, 32, 3))
plt.title(f"Dự đoán: {label_names[predicted_label]}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 99ms/step - accuracy: 0.0143 - loss: 4.6432 - val_accuracy: 0.0461 - val_loss: 4.2901
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 43s 104ms/step - accuracy: 0.0356 - loss: 4.3052 - val_accuracy: 0.0675 - val_loss: 4.1372
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 107ms/step - accuracy: 0.0519 - loss: 4.1661 - val_accuracy: 0.0839 - val_loss: 4.0442
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 81s 105ms/step - accuracy: 0.0617 - loss: 4.0943 - val_accuracy: 0.1054 - val_loss: 3.9888
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.0653 - loss: 4.0659 - val_accuracy: 0.1032 - val_loss: 3.9568
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.0734 - loss: 4.0197 - val_accuracy: 0.1005 - val_loss: 3.9900
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 103ms/step - accuracy: 0.0756 - loss: 3.9985 - val_accuracy: 0.1040 - val_loss: 3.9290
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.0803 - loss: 3.9701 - val_accuracy: 0.1056 - val_loss: 3.9392
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 100ms/step - accuracy: 0.0811 - loss: 3.9640 - val_accuracy: 0.1110 - val_loss: 3.9328
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - accuracy: 0.0853 - loss: 3.9539 - val_accuracy: 0.1140 - val_loss: 3.9033
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 97ms/step - accuracy: 0.0842 - loss: 3.9457 - val_accuracy: 0.1107 - val_loss: 3.8934
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 101ms/step - accuracy: 0.0865 - loss: 3.9347 - val_accuracy: 0.1243 - val_loss: 3.8797
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 101ms/step - accuracy: 0.0897 - loss: 3.9029 - val_accuracy: 0.1124 - val_loss: 3.8574
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 97ms/step - accuracy: 0.0902 - loss: 3.9089 - val_accuracy: 0.1170 - val_loss: 3.8809
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 96ms/step - accuracy: 0.0904 - loss: 3.8931 - val_accuracy: 0.1189 - val_loss: 3.8460
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 97ms/step - accuracy: 0.0932 - loss: 3.8978 - val_accuracy: 0.1069 - val_loss: 3.8689
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 45s 109ms/step - accuracy: 0.0935 - loss: 3.8919 - val_accuracy: 0.1194 - val_loss: 3.8368
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 80s 104ms/step - accuracy: 0.0979 - loss: 3.8728 - val_accuracy: 0.1204 - val_loss: 3.8559
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.0976 - loss: 3.8651 - val_accuracy: 0.1224 - val_loss: 3.8381
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 99ms/step - accuracy: 0.0952 - loss: 3.8586 - val_accuracy: 0.1207 - val_loss: 3.8389
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.1185 - loss: 3.8409
# Độ chính xác : 0.12070000171661377
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Ảnh được dự đoán là: chimpanzee

# %%
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.reshape(50000, 32 * 32 * 3).astype('float32') / 255.0
x_test = x_test.reshape(10000, 32 * 32 * 3).astype('float32') / 255.0

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(100, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=128,
                    validation_data=(x_test, y_test))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Độ chính xác :", test_acc)

img_path = '/content/drive/MyDrive/cifar/apple.webp'
img = load_img(img_path, target_size=(32, 32))
img = img_to_array(img).astype('float32') / 255.0
img = img.reshape(1, 32 * 32 * 3)

prediction = model.predict(img)
predicted_label = np.argmax(prediction)
label_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]


print("Ảnh được dự đoán là:", label_names[predicted_label])

plt.imshow(img.reshape(32, 32, 3))
plt.title(f"Dự đoán: {label_names[predicted_label]}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 99ms/step - accuracy: 0.0156 - loss: 4.6514 - val_accuracy: 0.0494 - val_loss: 4.2725
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.0378 - loss: 4.2982 - val_accuracy: 0.0689 - val_loss: 4.1123
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 43s 106ms/step - accuracy: 0.0508 - loss: 4.1767 - val_accuracy: 0.0736 - val_loss: 4.0742
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 81s 104ms/step - accuracy: 0.0556 - loss: 4.1331 - val_accuracy: 0.0868 - val_loss: 4.0315
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 95ms/step - accuracy: 0.0616 - loss: 4.0781 - val_accuracy: 0.0864 - val_loss: 4.0192
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 98ms/step - accuracy: 0.0642 - loss: 4.0663 - val_accuracy: 0.0853 - val_loss: 4.0096
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 101ms/step - accuracy: 0.0737 - loss: 4.0321 - val_accuracy: 0.1023 - val_loss: 3.9714
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 49s 125ms/step - accuracy: 0.0720 - loss: 4.0150 - val_accuracy: 0.1044 - val_loss: 3.9517
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 72s 101ms/step - accuracy: 0.0777 - loss: 3.9954 - val_accuracy: 0.0990 - val_loss: 3.9477
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.0790 - loss: 3.9672 - val_accuracy: 0.1061 - val_loss: 3.9311
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.0803 - loss: 3.9553 - val_accuracy: 0.1111 - val_loss: 3.8969
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 99ms/step - accuracy: 0.0821 - loss: 3.9439 - val_accuracy: 0.1098 - val_loss: 3.9032
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 103ms/step - accuracy: 0.0865 - loss: 3.9323 - val_accuracy: 0.1064 - val_loss: 3.8994
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 96ms/step - accuracy: 0.0848 - loss: 3.9295 - val_accuracy: 0.1113 - val_loss: 3.8900
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 99ms/step - accuracy: 0.0902 - loss: 3.9211 - val_accuracy: 0.1109 - val_loss: 3.8854
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 99ms/step - accuracy: 0.0902 - loss: 3.9044 - val_accuracy: 0.1223 - val_loss: 3.8796
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.0895 - loss: 3.8967 - val_accuracy: 0.1083 - val_loss: 3.9194
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 96ms/step - accuracy: 0.0898 - loss: 3.9053 - val_accuracy: 0.1109 - val_loss: 3.8933
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.0937 - loss: 3.8936 - val_accuracy: 0.1178 - val_loss: 3.8629
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 100ms/step - accuracy: 0.0951 - loss: 3.8816 - val_accuracy: 0.1133 - val_loss: 3.8738
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1121 - loss: 3.8770
# Độ chính xác : 0.11330000311136246
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Ảnh được dự đoán là: poppy

# %%
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.reshape(50000, 32 * 32 * 3).astype('float32') / 255.0
x_test = x_test.reshape(10000, 32 * 32 * 3).astype('float32') / 255.0

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(100, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=500,
                    validation_data=(x_test, y_test))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Độ chính xác :", test_acc)

img_path = '/content/drive/MyDrive/cifar/fox.png'
img = load_img(img_path, target_size=(32, 32))
img = img_to_array(img).astype('float32') / 255.0
img = img.reshape(1, 32 * 32 * 3)

prediction = model.predict(img)
predicted_label = np.argmax(prediction)
label_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]

print("Ảnh được dự đoán là:", label_names[predicted_label])

plt.imshow(img.reshape(32, 32, 3))
plt.title(f"Dự đoán: {label_names[predicted_label]}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 29s 277ms/step - accuracy: 0.0130 - loss: 4.6833 - val_accuracy: 0.0395 - val_loss: 4.3560
# Epoch 2/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 30s 305ms/step - accuracy: 0.0372 - loss: 4.3508 - val_accuracy: 0.0618 - val_loss: 4.1256
# Epoch 3/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 253ms/step - accuracy: 0.0520 - loss: 4.1890 - val_accuracy: 0.0769 - val_loss: 4.0361
# Epoch 4/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 256ms/step - accuracy: 0.0592 - loss: 4.1091 - val_accuracy: 0.0988 - val_loss: 3.9487
# Epoch 5/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 43s 274ms/step - accuracy: 0.0711 - loss: 4.0329 - val_accuracy: 0.1092 - val_loss: 3.9090
# Epoch 6/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 264ms/step - accuracy: 0.0788 - loss: 3.9870 - val_accuracy: 0.1244 - val_loss: 3.8518
# Epoch 7/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 25s 254ms/step - accuracy: 0.0846 - loss: 3.9399 - val_accuracy: 0.1251 - val_loss: 3.8386
# Epoch 8/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 254ms/step - accuracy: 0.0891 - loss: 3.9114 - val_accuracy: 0.1399 - val_loss: 3.7937
# Epoch 9/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - accuracy: 0.0954 - loss: 3.8753 - val_accuracy: 0.1434 - val_loss: 3.7714
# Epoch 10/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 243ms/step - accuracy: 0.1024 - loss: 3.8341 - val_accuracy: 0.1382 - val_loss: 3.7572
# Epoch 11/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 42s 253ms/step - accuracy: 0.1062 - loss: 3.8050 - val_accuracy: 0.1542 - val_loss: 3.7314
# Epoch 12/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 254ms/step - accuracy: 0.1061 - loss: 3.8033 - val_accuracy: 0.1442 - val_loss: 3.7310
# Epoch 13/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 244ms/step - accuracy: 0.1116 - loss: 3.7817 - val_accuracy: 0.1540 - val_loss: 3.7023
# Epoch 14/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 26s 263ms/step - accuracy: 0.1105 - loss: 3.7611 - val_accuracy: 0.1482 - val_loss: 3.7229
# Epoch 15/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 269ms/step - accuracy: 0.1180 - loss: 3.7431 - val_accuracy: 0.1547 - val_loss: 3.6856
# Epoch 16/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 254ms/step - accuracy: 0.1166 - loss: 3.7449 - val_accuracy: 0.1518 - val_loss: 3.6962
# Epoch 17/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 245ms/step - accuracy: 0.1176 - loss: 3.7356 - val_accuracy: 0.1572 - val_loss: 3.6844
# Epoch 18/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 42s 253ms/step - accuracy: 0.1198 - loss: 3.7143 - val_accuracy: 0.1603 - val_loss: 3.6918
# Epoch 19/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - accuracy: 0.1232 - loss: 3.6964 - val_accuracy: 0.1631 - val_loss: 3.6444
# Epoch 20/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - accuracy: 0.1269 - loss: 3.6854 - val_accuracy: 0.1687 - val_loss: 3.6545
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.1660 - loss: 3.6614
# Độ chính xác : 0.16869999468326569
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d6262077100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Ảnh được dự đoán là: tractor

# %%
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.reshape(50000, 32 * 32 * 3).astype('float32') / 255.0
x_test = x_test.reshape(10000, 32 * 32 * 3).astype('float32') / 255.0

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(100, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=500,
                    validation_data=(x_test, y_test))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Độ chính xác :", test_acc)

img_path = '/content/drive/MyDrive/cifar/rose.webp'
img = load_img(img_path, target_size=(32, 32))
img = img_to_array(img).astype('float32') / 255.0
img = img.reshape(1, 32 * 32 * 3)

prediction = model.predict(img)
predicted_label = np.argmax(prediction)
label_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]

print("Ảnh được dự đoán là:", label_names[predicted_label])

plt.imshow(img.reshape(32, 32, 3))
plt.title(f"Dự đoán: {label_names[predicted_label]}")
plt.axis('off')
plt.show()
# Out:
# Epoch 1/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 34s 315ms/step - accuracy: 0.0125 - loss: 4.6803 - val_accuracy: 0.0427 - val_loss: 4.3332
# Epoch 2/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 29s 294ms/step - accuracy: 0.0374 - loss: 4.3317 - val_accuracy: 0.0697 - val_loss: 4.0892
# Epoch 3/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 281ms/step - accuracy: 0.0538 - loss: 4.1686 - val_accuracy: 0.0877 - val_loss: 4.0190
# Epoch 4/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 254ms/step - accuracy: 0.0606 - loss: 4.1070 - val_accuracy: 0.1001 - val_loss: 3.9334
# Epoch 5/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 253ms/step - accuracy: 0.0706 - loss: 4.0500 - val_accuracy: 0.1172 - val_loss: 3.8874
# Epoch 6/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - accuracy: 0.0812 - loss: 3.9748 - val_accuracy: 0.1275 - val_loss: 3.8428
# Epoch 7/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 253ms/step - accuracy: 0.0893 - loss: 3.9370 - val_accuracy: 0.1280 - val_loss: 3.8156
# Epoch 8/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - accuracy: 0.0961 - loss: 3.8880 - val_accuracy: 0.1419 - val_loss: 3.7638
# Epoch 9/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 253ms/step - accuracy: 0.1017 - loss: 3.8525 - val_accuracy: 0.1491 - val_loss: 3.7222
# Epoch 10/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 265ms/step - accuracy: 0.1080 - loss: 3.8221 - val_accuracy: 0.1478 - val_loss: 3.7425
# Epoch 11/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 263ms/step - accuracy: 0.1104 - loss: 3.7975 - val_accuracy: 0.1513 - val_loss: 3.7016
# Epoch 12/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 42s 274ms/step - accuracy: 0.1161 - loss: 3.7842 - val_accuracy: 0.1574 - val_loss: 3.6886
# Epoch 13/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 261ms/step - accuracy: 0.1140 - loss: 3.7727 - val_accuracy: 0.1581 - val_loss: 3.6812
# Epoch 14/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 248ms/step - accuracy: 0.1174 - loss: 3.7629 - val_accuracy: 0.1582 - val_loss: 3.6625
# Epoch 15/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 253ms/step - accuracy: 0.1243 - loss: 3.7237 - val_accuracy: 0.1601 - val_loss: 3.6555
# Epoch 16/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 252ms/step - accuracy: 0.1254 - loss: 3.7211 - val_accuracy: 0.1625 - val_loss: 3.6723
# Epoch 17/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 264ms/step - accuracy: 0.1268 - loss: 3.6989 - val_accuracy: 0.1572 - val_loss: 3.6613
# Epoch 18/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 27s 273ms/step - accuracy: 0.1273 - loss: 3.7059 - val_accuracy: 0.1685 - val_loss: 3.6206
# Epoch 19/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 29s 286ms/step - accuracy: 0.1345 - loss: 3.6644 - val_accuracy: 0.1648 - val_loss: 3.6332
# Epoch 20/20
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 253ms/step - accuracy: 0.1320 - loss: 3.6540 - val_accuracy: 0.1688 - val_loss: 3.6037
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.1645 - loss: 3.6084
# Độ chính xác : 0.1687999963760376
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d626701bce0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Ảnh được dự đoán là: apple

# %%
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.reshape(50000, 32 * 32 * 3).astype('float32') / 255.0
x_test = x_test.reshape(10000, 32 * 32 * 3).astype('float32') / 255.0

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(100, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=500,
                    validation_data=(x_test, y_test))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Độ chính xác :", test_acc)

img_path = '/content/drive/MyDrive/cifar/3AXCDNT-003_7a321a47-7272-44d2-a054-371548190a38.webp'
img = load_img(img_path, target_size=(32, 32))
img = img_to_array(img).astype('float32') / 255.0
img = img.reshape(1, 32 * 32 * 3)

prediction = model.predict(img)
predicted_label = np.argmax(prediction)
label_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]

print("Ảnh được dự đoán là:", label_names[predicted_label])

plt.imshow(img.reshape(32, 32, 3))
plt.title(f"Dự đoán: {label_names[predicted_label]}")
plt.axis('off')
plt.show()

# %%
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.utils import to_categorical
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar100.load_data()

x_train = x_train.reshape(50000, 32 * 32 * 3).astype('float32') / 255.0
x_test = x_test.reshape(10000, 32 * 32 * 3).astype('float32') / 255.0

y_train = to_categorical(y_train, 100)
y_test = to_categorical(y_test, 100)

model = Sequential()
model.add(Dense(1024, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(100, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Huấn luyện mô hình
history = model.fit(x_train, y_train,
                    epochs=20,
                    batch_size=500,
                    validation_data=(x_test, y_test))

test_loss, test_acc = model.evaluate(x_test, y_test)
print("Độ chính xác :", test_acc)

img_path = '/content/drive/MyDrive/cifar/3AXCDNT-003_7a321a47-7272-44d2-a054-371548190a38.webp'
img = load_img(img_path, target_size=(32, 32))
img = img_to_array(img).astype('float32') / 255.0
img = img.reshape(1, 32 * 32 * 3)

prediction = model.predict(img)
predicted_label = np.argmax(prediction)
label_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle',
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel',
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock',
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]

print("Ảnh được dự đoán là:", label_names[predicted_label])

plt.imshow(img.reshape(32, 32, 3))
plt.title(f"Dự đoán: {label_names[predicted_label]}")
plt.axis('off')
plt.show()
